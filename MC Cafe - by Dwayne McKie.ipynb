# %%
# Welcome user to the MC Cafe
print(" ")
print(" ")
print("Welcome to MC Cafe!")

#create variable that will allow the user to choose to view the MC Cafe view (or not)
menu_view = "y"

print(" ")
print(" ")

#ask the user if he/she wants to view the MC Cafe menu
item_order = input("Do you want to see the menu?:  y/n  ")
print(" ")
print(" ")



#display the MC Cafe menu if the user chooses to do so
if item_order.lower() == 'y' :
    print(f"\t\tMC Cafe Menu")
    print(" ")
    print(f"\tCoffee")
    print(f"\t\tEspresso - $1.50")
    print(f"\t\tAmericano - $2.00")
    print(f"\t\tCaffe latte - $2.25")
    print(f"\t\tMocha - $2.25")
    print(f"\t\tCappucino - $2.50")
    print(f"\t\tMacchiato - $2.50")
    print(" ")
    print(f"\tTea")
    print(f"\t\tWhite tea - $1.50")
    print(f"\t\tGreen tea - $2.00")
    print(f"\t\tOolong tea - $2.25")
    print(f"\t\tBlack tea - $2.25")
    print(f"\t\tEarl Grey - $2.50")
    print(f"\t\tMatcha - $2.50")
    print(" ")
    print(f"\tPastries")
    print(f"\t\tCroissant - $5.50")
    print(f"\t\tCinnamon roll - $4.50")
    print(f"\t\tBanana bread - $4.25")
    print(f"\t\tPumpkin bread - $3.75")
    print(f"\t\tSticky bun - $4.25")
    print(f"\t\tApple turnover - $3.75")
    print(" ")




#initiate string variable that will store the name of the group of items (Coffee, Tea, Pastry)
item_group = " "

#initiate the integer variable of the number ordered of a particular item
item_amount = 0

#initiate the float variable of the price of the particular item ordered
item_price = 0.0

#initiate float variable that will store the total of the particular item ordered
#(item_amount * item_price)
item_total = 0.0

#initiate float variable that will store the amount (sub-total) of the order (before tax)
order_subtotal = 0.0

#initiate float variable that will store the taxable amount (sub-total) of the order
order_tax = 0.0

#initiate float variable that will store the total amonut (grand total) of the order
#(sub-total + taxable amount)
order_grand_total = 0.0

#create list that will store the elements of the order
#every 5 consecutive items in the list (quintuples) will be info associated with a particular item that is ordered
#item group, item ordered, number of item ordered (quantity), price of item, total price of the item ordered
menu_order = []


#create variable that will store value for continuation of placing order by user (or not)
answer = 'y'

#ask user if he/she wants to place an order
answer = input("Do you want to place an order:  y/n  ")

#allow user to not place an order
if answer.lower() == 'n' :
    menu_order.append("nothing")

#create loop that will allow user to place an order until the user decides that the order is completed
while answer.lower() != 'n' :
    print(" ")
    print(" ")

#ask user to order item
    print(" ")
    item_order = input("What food or drink do you want:    ")

#ask user the quantity/amount of item to order    
    print(" ")
    item_amount = int(input("Quantity:    "))
    
    print(" ")

#based on the item ordered, place the correct item group, price, in appropriate variables
    if item_order.lower() == "espresso" :
        item_price = 1.50
        item_group = "Coffee"
        item_order = "Espresso"
    elif item_order.lower() == "americano" :
        item_price = 2.00
        item_group = "Coffee"
        item_order = "Americano"
    elif item_order.lower() == "caffe latte" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Caffe latte"
    elif item_order.lower() == "mocha" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Mocha"
    elif item_order.lower() == "cappucino" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Cappucino"
    elif item_order.lower() == "macchiato" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Macchiato"
    elif item_order.lower() == "white tea" :
        item_price = 1.50
        item_group = "Tea"
        item_order = "White tea"
    elif item_order.lower() == "green tea" :
        item_price = 2.00
        item_group = "Tea"
        item_order = "Green tea"
    elif item_order.lower() == "oolong tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Oolong tea"
    elif item_order.lower() == "black tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Black tea"
    elif item_order.lower() == "earl grey" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Earl Grey"
    elif item_order.lower() == "matcha" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Matcha"
    elif item_order.lower() == "croissant" :
        item_price = 5.50
        item_group = "Pastry"
        item_order = "Croissant"
    elif item_order.lower() == "cinnamon roll" :
        item_price = 4.50
        item_group = "Pastry"
        item_order = "Cinnamon roll"
    elif item_order.lower() == "banana bread" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Banana bread"
    elif item_order.lower() == "pumpkin bread" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Pumpkin bread"
    elif item_order.lower() == "sticky bun" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Sticky bun"
    elif item_order.lower() == "apple turnover" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Apple turnover"
#if the item name is not part of the MC Cafe menu, inform the user and continue the ordering process
    else :
        print("The item entered is not on the menu...")
        continue
        
#add/append order information (item group, item ordered, number of item ordered, price of item) to the list
    menu_order.append(item_group)
    menu_order.append(item_order)
    menu_order.append(item_amount)
    menu_order.append(item_price)

#compute total price of the item ordered (quantity * price)
    item_total = item_amount * item_price
#add/append total price of item ordered to the list
    menu_order.append(item_total)

#keep a running total (sub-total) of the price of the item(s) ordered
    order_subtotal = order_subtotal + item_total

#ask the user if they want to continue placing the order (or not)
    print(" ")
    print(" ")
    answer = input("Do you want to add another item to your order? y/n:    ")

#initialize integer variable that will store the number of items (by item name) ordered 
order_length = 0

#calculate the number of items (by item name) ordered
#for each order (by item name), 5 consecutive pieces of information is associated with a particular order
order_length = len(menu_order)//5    
    
#print(len(menu_order))
#print(length)
    
#print(menu_order)
#print(f"Subtotal: ${order_subtotal:.2f}")

#computer taxable amount of the order (6% in the state of Maryland)
#order sub-total * 6%
order_tax = order_subtotal * 0.06

#compute the grand total of the order
#order sub-total + taxable amount
order_grand_total = order_subtotal + order_tax

print(" ")
print(" ")

#if user placed an order
if menu_order[0] != "nothing" :
#use for loop to print the items orders and the assocaited info for that particular item ordered
    for i in range(0, order_length) :
        print(f"Group:\t\t{menu_order[i*5]}")
        print(f"Item:\t\t{menu_order[i*5+1]}")
        print(f"Quantity:\t{menu_order[i*5+2]}")
        print(f"Price:\t\t$ {menu_order[i*5+3]:.2f}")
        print(f"Item Total:\t$ {menu_order[i*5+4]:.2f}")
        print(" ")

    print(" ")
    print(" ")

#print the order sub-total
    print(f"Subtotal:\t$ {order_subtotal:.2f}")

#print the taxable amount of the order
    print(f"Tax:\t\t$ {order_tax:.2f}")

#print the grand total of the order
    print(f"Total:\t\t$ {order_grand_total:.2f}")

#thank the user for visiting the MC Cafe
print(" ")
print(" ")
print("Thank you for visiting MC Cafe!")
# Out:
#
#
# Welcome to MC Cafe!
#
#
# Do you want to see the menu?:  y/n  y
#
#
# 		MC Cafe Menu
#
# 	Coffee
# 		Espresso - $1.50
# 		Americano - $2.00
# 		Caffe latte - $2.25
# 		Mocha - $2.25
# 		Cappucino - $2.50
# 		Macchiato - $2.50
#
# 	Tea
# 		White tea - $1.50
# 		Green tea - $2.00
# 		Oolong tea - $2.25
# 		Black tea - $2.25
# 		Earl Grey - $2.50
# 		Matcha - $2.50
#
# 	Pastries
# 		Croissant - $5.50
# 		Cinnamon roll - $4.50
# 		Banana bread - $4.25
# 		Pumpkin bread - $3.75
# 		Sticky bun - $4.25
# 		Apple turnover - $3.75
#
# Do you want to place an order:  y/n  y
#
#
#
# What food or drink do you want:    Cinnamon ROLL
#
# Quantity:    2
#
#
#
# Do you want to add another item to your order? y/n:    y
#
#
#
# What food or drink do you want:    vodka
#
# Quantity:    4
#
# The item entered is not on the menu...
#
#
#
# What food or drink do you want:    y
#
# Quantity:    5
#
# The item entered is not on the menu...
#
#
#
# What food or drink do you want:    GREEN TEA
#
# ...

# %%
# Welcome user to the MC Cafe
print(" ")
print(" ")
print("Welcome to MC Cafe!")

#create variable that will allow the user to choose to view the MC Cafe view (or not)
menu_view = "y"

print(" ")
print(" ")

#ask the user if he/she wants to view the MC Cafe menu
item_order = input("Do you want to see the menu?:  y/n  ")
print(" ")
print(" ")



#display the MC Cafe menu if the user chooses to do so
if item_order.lower() == 'y' :
    print(f"\t\tMC Cafe Menu")
    print(" ")
    print(f"\tCoffee")
    print(f"\t\tEspresso - $1.50")
    print(f"\t\tAmericano - $2.00")
    print(f"\t\tCaffe latte - $2.25")
    print(f"\t\tMocha - $2.25")
    print(f"\t\tCappucino - $2.50")
    print(f"\t\tMacchiato - $2.50")
    print(" ")
    print(f"\tTea")
    print(f"\t\tWhite tea - $1.50")
    print(f"\t\tGreen tea - $2.00")
    print(f"\t\tOolong tea - $2.25")
    print(f"\t\tBlack tea - $2.25")
    print(f"\t\tEarl Grey - $2.50")
    print(f"\t\tMatcha - $2.50")
    print(" ")
    print(f"\tPastries")
    print(f"\t\tCroissant - $5.50")
    print(f"\t\tCinnamon roll - $4.50")
    print(f"\t\tBanana bread - $4.25")
    print(f"\t\tPumpkin bread - $3.75")
    print(f"\t\tSticky bun - $4.25")
    print(f"\t\tApple turnover - $3.75")
    print(" ")




#initiate string variable that will store the name of the group of items (Coffee, Tea, Pastry)
item_group = " "

#initiate the integer variable of the number ordered of a particular item
item_amount = 0

#initiate the float variable of the price of the particular item ordered
item_price = 0.0

#initiate float variable that will store the total of the particular item ordered
#(item_amount * item_price)
item_total = 0.0

#initiate float variable that will store the amount (sub-total) of the order (before tax)
order_subtotal = 0.0

#initiate float variable that will store the taxable amount (sub-total) of the order
order_tax = 0.0

#initiate float variable that will store the total amonut (grand total) of the order
#(sub-total + taxable amount)
order_grand_total = 0.0

#create list that will store the elements of the order
#every 5 consecutive items in the list (quintuples) will be info associated with a particular item that is ordered
#item group, item ordered, number of item ordered (quantity), price of item, total price of the item ordered
menu_order = []


#create variable that will store value for continuation of placing order by user (or not)
answer = 'y'

#ask user if he/she wants to place an order
answer = input("Do you want to place an order:  y/n  ")

#allow user to not place an order
if answer.lower() == 'n' :
    menu_order.append("nothing")

#create loop that will allow user to place an order until the user decides that the order is completed
while answer.lower() != 'n' :
    print(" ")
    print(" ")

#ask user to order item
    print(" ")
    item_order = input("What food or drink do you want:    ")

#ask user the quantity/amount of item to order    
    print(" ")
    item_amount = int(input("Quantity:    "))
    
    print(" ")

#based on the item ordered, place the correct item group, price, in appropriate variables
    if item_order.lower() == "espresso" :
        item_price = 1.50
        item_group = "Coffee"
        item_order = "Espresso"
    elif item_order.lower() == "americano" :
        item_price = 2.00
        item_group = "Coffee"
        item_order = "Americano"
    elif item_order.lower() == "caffe latte" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Caffe latte"
    elif item_order.lower() == "mocha" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Mocha"
    elif item_order.lower() == "cappucino" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Cappucino"
    elif item_order.lower() == "macchiato" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Macchiato"
    elif item_order.lower() == "white tea" :
        item_price = 1.50
        item_group = "Tea"
        item_order = "White tea"
    elif item_order.lower() == "green tea" :
        item_price = 2.00
        item_group = "Tea"
        item_order = "Green tea"
    elif item_order.lower() == "oolong tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Oolong tea"
    elif item_order.lower() == "black tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Black tea"
    elif item_order.lower() == "earl grey" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Earl Grey"
    elif item_order.lower() == "matcha" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Matcha"
    elif item_order.lower() == "croissant" :
        item_price = 5.50
        item_group = "Pastry"
        item_order = "Croissant"
    elif item_order.lower() == "cinnamon roll" :
        item_price = 4.50
        item_group = "Pastry"
        item_order = "Cinnamon roll"
    elif item_order.lower() == "banana bread" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Banana bread"
    elif item_order.lower() == "pumpkin bread" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Pumpkin bread"
    elif item_order.lower() == "sticky bun" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Sticky bun"
    elif item_order.lower() == "apple turnover" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Apple turnover"
#if the item name is not part of the MC Cafe menu, inform the user and continue the ordering process
    else :
        print("The item entered is not on the menu...")
        continue
        
#add/append order information (item group, item ordered, number of item ordered, price of item) to the list
    menu_order.append(item_group)
    menu_order.append(item_order)
    menu_order.append(item_amount)
    menu_order.append(item_price)

#compute total price of the item ordered (quantity * price)
    item_total = item_amount * item_price
#add/append total price of item ordered to the list
    menu_order.append(item_total)

#keep a running total (sub-total) of the price of the item(s) ordered
    order_subtotal = order_subtotal + item_total

#ask the user if they want to continue placing the order (or not)
    print(" ")
    print(" ")
    answer = input("Do you want to add another item to your order? y/n:    ")

#initialize integer variable that will store the number of items (by item name) ordered 
order_length = 0

#calculate the number of items (by item name) ordered
#for each order (by item name), 5 consecutive pieces of information is associated with a particular order
order_length = len(menu_order)//5    
    
#print(len(menu_order))
#print(length)
    
#print(menu_order)
#print(f"Subtotal: ${order_subtotal:.2f}")

#computer taxable amount of the order (6% in the state of Maryland)
#order sub-total * 6%
order_tax = order_subtotal * 0.06

#compute the grand total of the order
#order sub-total + taxable amount
order_grand_total = order_subtotal + order_tax

print(" ")
print(" ")

#if user placed an order
if menu_order[0] != "nothing" :
#use for loop to print the items orders and the assocaited info for that particular item ordered
    for i in range(0, order_length) :
        print(f"Group:\t\t{menu_order[i*5]}")
        print(f"Item:\t\t{menu_order[i*5+1]}")
        print(f"Quantity:\t{menu_order[i*5+2]}")
        print(f"Price:\t\t$ {menu_order[i*5+3]:.2f}")
        print(f"Item Total:\t$ {menu_order[i*5+4]:.2f}")
        print(" ")

    print(" ")
    print(" ")

#print the order sub-total
    print(f"Subtotal:\t$ {order_subtotal:.2f}")

#print the taxable amount of the order
    print(f"Tax:\t\t$ {order_tax:.2f}")

#print the grand total of the order
    print(f"Total:\t\t$ {order_grand_total:.2f}")

#thank the user for visiting the MC Cafe
print(" ")
print(" ")
print("Thank you for visiting MC Cafe!")
# Out:
#
#
# Welcome to MC Cafe!
#
#
# Do you want to see the menu?:  y/n  n
#
#
# Do you want to place an order:  y/n  n
#
#
#
#
# Thank you for visiting MC Cafe!

# %%
# Welcome user to the MC Cafe
print(" ")
print(" ")
print("Welcome to MC Cafe!")

#create variable that will allow the user to choose to view the MC Cafe view (or not)
menu_view = "y"

print(" ")
print(" ")

#ask the user if he/she wants to view the MC Cafe menu
item_order = input("Do you want to see the menu?:  y/n  ")
print(" ")
print(" ")



#display the MC Cafe menu if the user chooses to do so
if item_order.lower() == 'y' :
    print(f"\t\tMC Cafe Menu")
    print(" ")
    print(f"\tCoffee")
    print(f"\t\tEspresso - $1.50")
    print(f"\t\tAmericano - $2.00")
    print(f"\t\tCaffe latte - $2.25")
    print(f"\t\tMocha - $2.25")
    print(f"\t\tCappucino - $2.50")
    print(f"\t\tMacchiato - $2.50")
    print(" ")
    print(f"\tTea")
    print(f"\t\tWhite tea - $1.50")
    print(f"\t\tGreen tea - $2.00")
    print(f"\t\tOolong tea - $2.25")
    print(f"\t\tBlack tea - $2.25")
    print(f"\t\tEarl Grey - $2.50")
    print(f"\t\tMatcha - $2.50")
    print(" ")
    print(f"\tPastries")
    print(f"\t\tCroissant - $5.50")
    print(f"\t\tCinnamon roll - $4.50")
    print(f"\t\tBanana bread - $4.25")
    print(f"\t\tPumpkin bread - $3.75")
    print(f"\t\tSticky bun - $4.25")
    print(f"\t\tApple turnover - $3.75")
    print(" ")




#initiate string variable that will store the name of the group of items (Coffee, Tea, Pastry)
item_group = " "

#initiate the integer variable of the number ordered of a particular item
item_amount = 0

#initiate the float variable of the price of the particular item ordered
item_price = 0.0

#initiate float variable that will store the total of the particular item ordered
#(item_amount * item_price)
item_total = 0.0

#initiate float variable that will store the amount (sub-total) of the order (before tax)
order_subtotal = 0.0

#initiate float variable that will store the taxable amount (sub-total) of the order
order_tax = 0.0

#initiate float variable that will store the total amonut (grand total) of the order
#(sub-total + taxable amount)
order_grand_total = 0.0

#create list that will store the elements of the order
#every 5 consecutive items in the list (quintuples) will be info associated with a particular item that is ordered
#item group, item ordered, number of item ordered (quantity), price of item, total price of the item ordered
menu_order = []


#create variable that will store value for continuation of placing order by user (or not)
answer = 'y'

#ask user if he/she wants to place an order
answer = input("Do you want to place an order:  y/n  ")

#allow user to not place an order
if answer.lower() == 'n' :
    menu_order.append("nothing")

#create loop that will allow user to place an order until the user decides that the order is completed
while answer.lower() != 'n' :
    print(" ")
    print(" ")

#ask user to order item
    print(" ")
    item_order = input("What food or drink do you want:    ")

#ask user the quantity/amount of item to order    
    print(" ")
    item_amount = int(input("Quantity:    "))
    
    print(" ")

#based on the item ordered, place the correct item group, price, in appropriate variables
    if item_order.lower() == "espresso" :
        item_price = 1.50
        item_group = "Coffee"
        item_order = "Espresso"
    elif item_order.lower() == "americano" :
        item_price = 2.00
        item_group = "Coffee"
        item_order = "Americano"
    elif item_order.lower() == "caffe latte" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Caffe latte"
    elif item_order.lower() == "mocha" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Mocha"
    elif item_order.lower() == "cappucino" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Cappucino"
    elif item_order.lower() == "macchiato" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Macchiato"
    elif item_order.lower() == "white tea" :
        item_price = 1.50
        item_group = "Tea"
        item_order = "White tea"
    elif item_order.lower() == "green tea" :
        item_price = 2.00
        item_group = "Tea"
        item_order = "Green tea"
    elif item_order.lower() == "oolong tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Oolong tea"
    elif item_order.lower() == "black tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Black tea"
    elif item_order.lower() == "earl grey" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Earl Grey"
    elif item_order.lower() == "matcha" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Matcha"
    elif item_order.lower() == "croissant" :
        item_price = 5.50
        item_group = "Pastry"
        item_order = "Croissant"
    elif item_order.lower() == "cinnamon roll" :
        item_price = 4.50
        item_group = "Pastry"
        item_order = "Cinnamon roll"
    elif item_order.lower() == "banana bread" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Banana bread"
    elif item_order.lower() == "pumpkin bread" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Pumpkin bread"
    elif item_order.lower() == "sticky bun" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Sticky bun"
    elif item_order.lower() == "apple turnover" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Apple turnover"
#if the item name is not part of the MC Cafe menu, inform the user and continue the ordering process
    else :
        print("The item entered is not on the menu...")
        continue
        
#add/append order information (item group, item ordered, number of item ordered, price of item) to the list
    menu_order.append(item_group)
    menu_order.append(item_order)
    menu_order.append(item_amount)
    menu_order.append(item_price)

#compute total price of the item ordered (quantity * price)
    item_total = item_amount * item_price
#add/append total price of item ordered to the list
    menu_order.append(item_total)

#keep a running total (sub-total) of the price of the item(s) ordered
    order_subtotal = order_subtotal + item_total

#ask the user if they want to continue placing the order (or not)
    print(" ")
    print(" ")
    answer = input("Do you want to add another item to your order? y/n:    ")

#initialize integer variable that will store the number of items (by item name) ordered 
order_length = 0

#calculate the number of items (by item name) ordered
#for each order (by item name), 5 consecutive pieces of information is associated with a particular order
order_length = len(menu_order)//5    
    
#print(len(menu_order))
#print(length)
    
#print(menu_order)
#print(f"Subtotal: ${order_subtotal:.2f}")

#computer taxable amount of the order (6% in the state of Maryland)
#order sub-total * 6%
order_tax = order_subtotal * 0.06

#compute the grand total of the order
#order sub-total + taxable amount
order_grand_total = order_subtotal + order_tax

print(" ")
print(" ")

#if user placed an order
if menu_order[0] != "nothing" :
#use for loop to print the items orders and the assocaited info for that particular item ordered
    for i in range(0, order_length) :
        print(f"Group:\t\t{menu_order[i*5]}")
        print(f"Item:\t\t{menu_order[i*5+1]}")
        print(f"Quantity:\t{menu_order[i*5+2]}")
        print(f"Price:\t\t$ {menu_order[i*5+3]:.2f}")
        print(f"Item Total:\t$ {menu_order[i*5+4]:.2f}")
        print(" ")

    print(" ")
    print(" ")

#print the order sub-total
    print(f"Subtotal:\t$ {order_subtotal:.2f}")

#print the taxable amount of the order
    print(f"Tax:\t\t$ {order_tax:.2f}")

#print the grand total of the order
    print(f"Total:\t\t$ {order_grand_total:.2f}")

#thank the user for visiting the MC Cafe
print(" ")
print(" ")
print("Thank you for visiting MC Cafe!")
# Out:
#
#
# Welcome to MC Cafe!
#
#
# Do you want to see the menu?:  y/n  y
#
#
# 		MC Cafe Menu
#
# 	Coffee
# 		Espresso - $1.50
# 		Americano - $2.00
# 		Caffe latte - $2.25
# 		Mocha - $2.25
# 		Cappucino - $2.50
# 		Macchiato - $2.50
#
# 	Tea
# 		White tea - $1.50
# 		Green tea - $2.00
# 		Oolong tea - $2.25
# 		Black tea - $2.25
# 		Earl Grey - $2.50
# 		Matcha - $2.50
#
# 	Pastries
# 		Croissant - $5.50
# 		Cinnamon roll - $4.50
# 		Banana bread - $4.25
# 		Pumpkin bread - $3.75
# 		Sticky bun - $4.25
# 		Apple turnover - $3.75
#
# Do you want to place an order:  y/n  n
#
#
#
#
# Thank you for visiting MC Cafe!
